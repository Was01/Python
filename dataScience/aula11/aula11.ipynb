# %% [markdown]
# ## Aula 11 - Criando e removendo colunas do DataFrame

# %%
import pandas as pd
import numpy as np
from random import choice

# %%
df=pd.read_excel('dados-aula11.xlsx')
df
# Out:
#    Massa corporal (kg)  Altura (cm)
# 0                   72          180
# 1                   80          170
# 2                   60          175
# 3                   90          174
# 4                  100          185

# %%
df.shape
# Out:
# (5, 2)

# %%
idade=np.random.randint(17,40,5)
idade
# Out:
# array([29, 21, 17, 20, 30])

# %%
df.columns
# Out:
# Index(['Massa corporal (kg)', 'Altura (cm)'], dtype='object')

# %%
df['Idade']=idade
df
# Out:
#    Massa corporal (kg)  Altura (cm)  Idade
# 0                   72          180     29
# 1                   80          170     21
# 2                   60          175     17
# 3                   90          174     20
# 4                  100          185     30

# %%
sexo=[choice(['Feminino','Masculino']) for i in range(5)]
df['Sexo']=sexo
df
# Out:
#    Massa corporal (kg)  Altura (cm)  Idade       Sexo
# 0                   72          180     29   Feminino
# 1                   80          170     21  Masculino
# 2                   60          175     17   Feminino
# 3                   90          174     20   Feminino
# 4                  100          185     30  Masculino

# %%
#Removendo linhas e colunas
df.drop('Altura (cm)',axis=1)
# Out:
#    Massa corporal (kg)  Idade       Sexo
# 0                   72     29   Feminino
# 1                   80     21  Masculino
# 2                   60     17   Feminino
# 3                   90     20   Feminino
# 4                  100     30  Masculino

# %%
df.drop(0)
# Out:
#    Massa corporal (kg)  Altura (cm)  Idade       Sexo
# 1                   80          170     21  Masculino
# 2                   60          175     17   Feminino
# 3                   90          174     20   Feminino
# 4                  100          185     30  Masculino
