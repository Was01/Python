# %%
import numpy as np
import pandas as pd

# %%
dados=np.array([[72,160,26],[80,170,19],[60,165,15]])
dados
# Out:
# array([[ 72, 160,  26],
#        [ 80, 170,  19],
#        [ 60, 165,  15]])

# %%
df=pd.DataFrame(data=dados,columns=['Peso','Altura','Idade'])
df
# Out:
#    Peso  Altura  Idade
# 0    72     160     26
# 1    80     170     19
# 2    60     165     15

# %%
## indexação

# %%
df['Altura']
# Out:
# 0    160
# 1    170
# 2    165
# Name: Altura, dtype: int64

# %%
df.loc[2]
# Out:
# Peso       60
# Altura    165
# Idade      15
# Name: 2, dtype: int64

# %%
df.loc[0]['Altura']
# Out:
# np.int64(160)

# %%
df.iloc[2][1]
# Out:
# /tmp/ipython-input-2023769522.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[2][1]
# np.int64(165)
