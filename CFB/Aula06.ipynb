# %%
curso="Curso de Python  ".strip() #retira espações espaços no ínicio e no fim da string
print(curso)
print("Tamanho: "+str(len(curso)))
# Out:
# Curso de Python
# Tamanho: 15

# %%
print(curso[:5])
print(curso[9:])
# Out:
# Curso
# Python

# %%
print(curso.lower()) #Converte toda a string para minúsculas
# Out:
# curso de python

# %%
print(curso.upper())#Converte toda a string para maiúsculas
# Out:
# CURSO DE PYTHON

# %%
print(curso.replace('Python','Java'))
# Out:
# Curso de Java

# %%
a=curso.split(' ')
for i in range(len(a)):
  print(a[i])
# Out:
# Curso
# de
# Python
